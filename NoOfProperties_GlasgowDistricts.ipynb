# %% [markdown]
# <a href="https://colab.research.google.com/github/sysphcd/Fuel-Poverty-Project/blob/main/NoOfProperties_GlasgowDistricts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysing Number of Properties in Glasgow and Plotting Choropleth Maps using plotly

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)

# %%
import json
import numpy as np
import pandas as pd

from google.colab import drive
drive.mount("/content/drive")

import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'colab'

import requests
from bs4 import BeautifulSoup
# Out:
# Mounted at /content/drive

# %%
#Scraping data from web and saving into pandas dataframe
res = requests.get("https://en.wikipedia.org/wiki/G_postcode_area")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[1]
df = pd.read_html(str(table))
Glasgow_df=pd.DataFrame(df[0])
display(Glasgow_df.head())
#Printing the shape of the data frame before Preprocessing 
print(Glasgow_df.shape)
# Out:
#   Postcode district Post town  \
# 0                G1   GLASGOW
# 1                G2   GLASGOW
# 2                G3   GLASGOW
# 3                G4   GLASGOW
# 4                G5   GLASGOW
#
#                                             Coverage Local authority area(s)
# 0                  Former C1 district: Merchant City            Glasgow City
# 1  Former C2 district: Blythswood Hill, Anderston...            Glasgow City
# 2  Former C3 district: Anderston, Finnieston, Gar...            Glasgow City
# 3  Former C4 district: Calton (part), Cowcaddens ...            Glasgow City
# 4                        Former C5 district: Gorbals            Glasgow City
# (55, 4)

# %%
# Droping the entries where the Local authority area is not defined
Glasgow_df=Glasgow_df[Glasgow_df['Local authority area(s)'] != 'non-geographic']
Glasgow_df= Glasgow_df[Glasgow_df['Postcode district']!='G51 2']
Glasgow_df=Glasgow_df.reset_index(drop=True,inplace=False)
Glasgow_df['Postcode district']= Glasgow_df['Postcode district'].str.rsplit(" ", n =0 , expand = False).str[0]

# Removing the former district information from the Coverage column 
for n in range (Glasgow_df.shape[0]):
    if ': ' in Glasgow_df['Coverage'][n]:
        t=Glasgow_df['Coverage'][n]
        Glasgow_df['Coverage'][n]=t.split(': ',2)[1]
Glasgow_df.head()
# Out:
#   Postcode district Post town  \
# 0                G1   GLASGOW
# 1                G2   GLASGOW
# 2                G3   GLASGOW
# 3                G4   GLASGOW
# 4                G5   GLASGOW
#
#                                             Coverage Local authority area(s)
# 0                                      Merchant City            Glasgow City
# 1                  Blythswood Hill, Anderston (part)            Glasgow City
# 2  Anderston, Finnieston, Garnethill, Park, Woodl...            Glasgow City
# 3  Calton (part), Cowcaddens (part), Drygate, Kel...            Glasgow City
# 4                                            Gorbals            Glasgow City

# %%
# Forming a new Column called District which is the first area in the coverage column (This will be used to find the Latitude and Longitude Information)  
Glasgow_df['District']= Glasgow_df['Coverage'].str.rsplit(",", n =0 , expand = False).str[0] 
Glasgow_df['District']= Glasgow_df['District'].str.rsplit("(", n =0 , expand = False).str[0]
Glasgow_df['District'][47]='Hardgate'

# %%
def get_file(filename):
  try:
       file = open("/content/drive/My Drive/Colab Notebooks/Datasets/"+filename, mode='rb')
       return file
  except:
    #with open("valid_file.txt", mode="x") as file:
    print("File does not exist")
    return None
  #else:

# %%
pd.set_option("display.max.columns", None)

# %%
glasgow_areas = json.load(open("/content/drive/My Drive/Colab Notebooks/Datasets/glasgowgeo.geojson", "r"))

# %%
glasgow_districts_map = {}
for feature in glasgow_areas["features"]:
    feature["area_name"] = feature["properties"]["description"]
    glasgow_districts_map[feature["properties"]["name"]] = feature["area_name"]
display(glasgow_districts_map)
# Out:
# {'G1': 'Merchant City',
#  'G11': 'Broomhill, Partick, Partickhill',
#  'G12': 'West End, Cleveden, Dowanhill, Hillhead, Hyndland, Kelvindale, Botanic Gardens',
#  'G13': 'Anniesland, Knightswood, Yoker',
#  'G14': 'Whiteinch, Scotstoun',
#  'G15': 'Drumchapel',
#  'G2': 'Blythswood Hill',
#  'G20': 'Maryhill, North Kelvinside, Ruchill',
#  'G21': 'Barmulloch, Cowlairs, Royston, Springburn, Sighthill',
#  'G22': 'Milton, Possilpark',
#  'G23': 'Lambhill, Summerston',
#  'G3': 'Anderston, Finnieston, Garnethill, Park, Woodlands, Yorkhill',
#  'G31': 'Dennistoun, Haghill, Parkhead',
#  'G32': 'Carmyle, Tollcross, Mount Vernon, Lightburn, Sandyhills',
#  'G33': 'Carntyne, Craigend, Cranhill, Millerston, Provanmill, Riddrie, Robroyston, Ruchazie, Stepps',
#  'G34': 'Easterhouse',
#  'G4': 'Calton, Cowcaddens, Drygate, Kelvinbridge, Townhead, Woodlands, Woodside',
#  'G40': 'Bridgeton, Calton',
#  'G41': 'Pollokshields, Shawlands',
#  'G42': 'Battlefield, Govanhill, Mount Florida, Strathbungo East',
#  'G43': 'Mansewood, Newlands, Pollokshaws',
#  'G44': "Cathcart, Croftfoot, King's Park, Muirend, Netherlee",
#  'G45': 'Castlemilk',
#  'G46': 'Giffnock, Kennishead, Thornliebank, Deaconsbank',
#  'G5': 'Gorbals',
#  'G51': 'Govan, Ibrox',
#  'G52': 'Cardonald, Hillington, Penilee',
#  'G53': 'Darnley, Pollok, Crookston',
#  'G60': 'Bowling, Old Kilpatrick, West Dunbartonshire',
#  'G61': 'Bearsden, East Dunbartonshire',
#  'G62': 'Milngavie, East Dunbartonshire',
#  'G63': 'Balfron, Blanefield, Croftamie, Drymen, Dumgoyne, Fintry, Killearn, Strathblane, Stirling',
#  'G64': 'Bishopbriggs, Torrance, East Dunbartonshire',
#  'G65': 'Croy, Kilsyth, North Lanarkshire',
#  'G66': 'Kirkintilloch, Lennoxtown, Lenzie, Milton of Campsie, East Dunbartonshire',
#  'G67': 'Cumbernauld, North Lanarkshire',
#  'G68': 'Cumbernauld, Dullatur, North Lanarkshire',
#  'G69': 'Baillieston, Garrowhill, Gartcosh, Moodiesburn, Muirhead',
#  'G71': 'Bothwell, Uddingston, Lanarkshire',
#  'G72': 'Blantyre, Cambuslang, South Lanarkshire',
#  'G73': 'Rutherglen, South Lanarkshire',
#  'G74': 'East Kilbride, Thorntonhall, South Lanarkshire',
#  'G75': 'East Kilbride, South Lanarkshire',
#  'G76': 'Busby, Clarkston, Eaglesham, Waterfoot, East Renfrewshire',
#  'G77': 'Newton Mearns, East Renfrewshire',
#  'G78': 'Barrhead, Neilston, Uplawmoor, East Renfrewshire',
#  'G81': 'Dalmuir, Duntocher, Faifley, Hardgate, West Dunbartonshire',
#  'G82': 'Cardross, Milton, West Dunbartonshire',
#  'G83': 'Ardlui, Balloch, Bonhill, Gartocharn, Luss, Renton, Tarbet, West Dunbartonshire',
#  'G84': 'Clynder, Cove, Garelochhead, Kilcreggan, Rhu, Rosneath, Shandon, Argyll and Bute'}

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Datasets/Housing_Association_Properties.csv")
df["district_code"] = df["POSTCODE"].apply(lambda x: x.split(" ")[0])
df["district_name"] = df["district_code"].apply(lambda x: glasgow_districts_map[x])
total_noofproperties_district = df.groupby(by=["district_code"])["NO_OF_PROPERTIES"].sum() 
df["percent_noofproperties_district"] = 100 * df['NO_OF_PROPERTIES'] / df.groupby('district_code')['NO_OF_PROPERTIES'].transform('sum')
display(df)
# Out:
#               X          Y  OBJECTID POSTCODE  NO_OF_PROPERTIES  \
# 0     -4.324043  55.873935         1  G11 7AX                 2
# 1     -4.300578  55.873744         2  G11 5HA                22
# 2     -4.314522  55.867901         3  G11 6BQ                44
# 3     -4.324773  55.878672         4  G11 7AZ                22
# 4     -4.300006  55.873530         5  G11 5HB                 9
# ...         ...        ...       ...      ...               ...
# 13072 -4.367722  55.807025     13073  G78 1TE                 6
# 13073 -4.369320  55.808132     13074  G78 1TF                 4
# 13074 -4.356328  55.795407     13075  G78 2FH                 2
# 13075 -4.381345  55.896779     13076  G81 1ET                 8
# 13076 -4.383318  55.894251     13077  G81 1EW                 6
#
#        NO_OF_HA_PROPERTIES  F__HA_OF_POSTCODE_TOTAL  NO_OF_OTHER_PROPERTIES  \
# 0                        0                        0                       2
# 1                        0                        0                      22
# 2                        0                        0                      44
# 3                        0                        0                      22
# 4                        0                        0                       9
# ...                    ...                      ...                     ...
# 13072                    0                        0                       6
# 13073                    0                        0                       4
# 13074                    0                        0                       2
# 13075                    3                        0                       5
# 13076                    0                        0                       6
#
#        F__OTHER_OF_POSTCODE_TOTAL  ADDRESS   LATITUDE  LONGITUDE  EASTING  \
# 0                               1  G11 7AX  55.873935  -4.324043   254692
# 1                               1  G11 5HA  55.873744  -4.300578   256159
# 2                               1  G11 6BQ  55.867901  -4.314522   255265
# 3                               1  G11 7AZ  55.878672  -4.324773   254664
# 4                               1  G11 5HB  55.873530  -4.300006   256194
# ...                           ...      ...        ...        ...      ...
# 13072                           1  G78 1TE  55.807025  -4.367722   251705
# 13073                           1  G78 1TF  55.808132  -4.369320   251609
# 13074                           1  G78 2FH  55.795407  -4.356328   252375
# 13075                           1  G81 1ET  55.896779  -4.381345   251195
# 13076                           1  G81 1EW  55.894251  -4.383318   251062
#
#        NORTHING         CONSTITUENCY                     WARD  \
# 0        666972   Glasgow North West            Victoria Park
# 1        666902        Glasgow North  Partick East/Kelvindale
# 2        666281   Glasgow North West            Victoria Park
# 3        667501   Glasgow North West            Victoria Park
# 4        666877        Glasgow North  Partick East/Kelvindale
# ...         ...                  ...                      ...
# 13072    659620   Glasgow South West           Greater Pollok
# 13073    659747   Glasgow South West           Greater Pollok
# 13074    658303   Glasgow South West           Greater Pollok
# 13075    669636  West Dunbartonshire     Clydebank Waterfront
# 13076    669359  West Dunbartonshire     Clydebank Waterfront
#
#                                          LSOA  REGION  LSOA_CODE  ROW_NUMBER  \
# 0                              Broomhill - 01     NaN  S01010415         402
# 1             Kelvingrove and University - 07     NaN  S01010380         202
# 2      Glasgow Harbour and Partick South - 05     NaN  S01010392         302
# 3                              Broomhill - 03     NaN  S01010417         403
# 4             Kelvingrove and University - 07     NaN  S01010380         203
# ...                                       ...     ...        ...         ...
# 13072                      Darnley North - 04     NaN  S01009767       13077
# 13073                      Darnley North - 04     NaN  S01009767       13078
# 13074                      Darnley North - 04     NaN  S01009767       13079
# 13075                               IZ01 - 05     NaN  S01013126       13080
# 13076                               IZ01 - 04     NaN  S01013125       13081
#
#       district_code                                      district_name  \
# 0               G11                    Broomhill, Partick, Partickhill
# 1               G11                    Broomhill, Partick, Partickhill
# 2               G11                    Broomhill, Partick, Partickhill
# 3               G11                    Broomhill, Partick, Partickhill
# 4               G11                    Broomhill, Partick, Partickhill
# ...             ...                                                ...
# 13072           G78   Barrhead, Neilston, Uplawmoor, East Renfrewshire
# 13073           G78   Barrhead, Neilston, Uplawmoor, East Renfrewshire
# 13074           G78   Barrhead, Neilston, Uplawmoor, East Renfrewshire
# 13075           G81  Dalmuir, Duntocher, Faifley, Hardgate, West Du...
# 13076           G81  Dalmuir, Duntocher, Faifley, Hardgate, West Du...
#
#        percent_noofproperties_district
# 0                             0.012832
# 1                             0.141152
# 2                             0.282305
# 3                             0.141152
# 4                             0.057744
# ...                                ...
# 13072                        46.153846
# 13073                        30.769231
# 13074                        15.384615
# 13075                        57.142857
# 13076                        42.857143
#
# [13077 rows x 23 columns]

# %%
fig = px.choropleth(
    df,
    locations="district_code",
    geojson=glasgow_areas,
    color="percent_noofproperties_district",
    hover_name="district_name",
    hover_data=["NO_OF_PROPERTIES"],
    title="Glasgow number of properties"
)
fig.update_geos(fitbounds="locations", visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f0d5592c-ae68-48be-a808-72f273dff69f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0d5592c-ae68-48be-a808-72f273dff69f")) {                    Plotly.newPlot(                        "f0d5592c-ae68-48be-a808-72f273dff69f",                        [{"coloraxis":"coloraxis","customdata":[[2],[22],[44],[22],[9],[17],[68],[51],[24],[27],[23],[31],[24],[16],[3],[50],[35],[42],[17],[36],[12],[20],[55],[20],[47],[12],[10],[13],[64],[30],[56],[8],[24],[1],[21],[12],[14],[29],[1],[41],[1],[10],[67],[18],[20],[7],[7],[16],[12],[3],[8],[6],[7],[15],[12],[18],[12],[10],[24],[10],[10],[32],[32],[26],[37],[39],[37],[27],[30],[14],[16],[4],[10],[1],[16],[12],[14],[17],[26],[22],[30],[40],[40],[16],[16],[56],[32],[4],[7],[1],[40],[16],[54],[64],[45],[34],[48],[64],[8],[44],[56],[8],[8],[31],[30],[31],[26],[2],[4],[11],[2],[7],[23],[17],[2],[31],[33],[35],[98],[3],[89],[61],[29],[48],[52],[66],[48],[96],[47],[3],[14],[21],[50],[13],[15],[34],[8],[12],[1],[58],[88],[23],[69],[482],[15],[62],[6],[29],[26],[57],[46],[24],[60],[90],[73],[5],[5],[31],[83],[115],[7],[310],[24],[52],[26],[10],[384],[24],[42],[11],[62],[13],[14],[18],[35],[15],[9],[1],[25],[29],[28],[11],[25],[41],